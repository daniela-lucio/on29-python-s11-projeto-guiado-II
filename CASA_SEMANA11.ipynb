# %% [markdown]
# <a href="https://colab.research.google.com/github/daniela-lucio/on29-python-s11-projeto-guiado-II/blob/main/CASA_SEMANA11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import jupyter as jup

# %%
import sqlite3

# %%
import csv

# %%
import pandas as pd

# %%
import numpy as np

# %%
file = open('COVID_INT_2020.xlsx')

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('COVID_INT_2020.xlsx')

# %%
df
# Out:
#          Município  População MACRO   RS   Fem  Masc  Branca  Preta  Amarela  \
# 0      AGUA BRANCA      10306    3ª  11ª   4.0     7     0.0    0.0      0.0
# 1           AGUIAR       5630    3ª   7ª   3.0     1     1.0    0.0      0.0
# 2    ALAGOA GRANDE      28439    2ª   3ª  31.0    35     7.0    3.0      3.0
# 3      ALAGOA NOVA      20921    2ª   3ª   6.0    10     0.0    0.0      0.0
# 4        ALAGOINHA      14560    1ª   2ª  15.0    13     2.0    2.0      1.0
# ..             ...        ...   ...  ...   ...   ...     ...    ...      ...
# 218        UIRAUNA      15300    3ª   9ª  15.0    18     5.0    1.0      0.0
# 219      UMBUZEIRO       9911    2ª  15ª   1.0     3     1.0    0.0      0.0
# 220         VARZEA       2841    3ª   6ª   2.0     1     0.0    0.0      0.0
# 221    VIEIROPOLIS       5372    3ª  10ª   2.0     3     0.0    0.0      0.0
# 222         ZABELE       2255    2ª   5ª   1.0     1     1.0    0.0      0.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
obitos = df['obitos'].value_counts()
obitos.plot(kind = 'bar', edgecolor = 'blue', color = 'pink')
plt.title('Número de óbitos por município')
plt.xlabel('Município')
plt.ylabel('obitos')
plt.show()

# %%
df['IDH'].plot.hist()
plt.show()

# %%
df_covid = pd.read_excel('COVID_INT_2020.xlsx')

# %%
casos_hospitalizacao = df['casos_hosp'].value_counts()
casos_hospitalizacao.plot(kind = 'bar', edgecolor = 'blue', color = 'pink')
plt.title('Hospitalizações por covid por macrorregião de saúde')
plt.xlabel('MACRO')
plt.ylabel('casos_hosp')
plt.show()

# %%
df['tx_urb'].plot.hist()
plt.show()
